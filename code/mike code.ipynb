# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
#city_data_to_load = "data/city_data.csv"
#ride_data_to_load = "data/ride_data.csv"
nfl_data_to_load =  pd.read_csv("../data/mike.csv")
#ride_data_to_load =  pd.read_csv("data/ride_data.csv", index_col ="city")
n_games_df = pd.DataFrame(nfl_data_to_load)
# Out:
# C:\Users\hanki\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (42,166,167,168,169,174,175,178,179,182,183,188,189,190,191,194,195,203,204,205,218,219,220,231,232,233,238,240,241,249) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
setitupz = n_games_df.groupby(['game_id', 'home_team','away_team'])
#setitupz['total_home_score'].max()
#setitupz['total_away_score'].max()
#setitupz['pass_attempt'].sum()
#setitupz['rush_attempt'].sum()

df_final=pd.DataFrame({'home_score':setitupz['total_home_score'].max(),'away_score':setitupz['total_away_score'].max(),'pass attempts':setitupz['pass_attempt'].sum(),' rush attempts':setitupz['rush_attempt'].sum()})


df_final
# Out:
#                                 home_score  away_score  pass attempts  \
# game_id    home_team away_team
# 2009091000 PIT       TEN                13          10           83.0
# 2009091300 ATL       MIA                19           7           72.0
# 2009091301 BAL       KC                 38          23           71.0
# 2009091302 CAR       PHI                10          36           70.0
# 2009091303 CIN       DEN                 7          12           68.0
# 2009091304 CLE       MIN                19          34           66.0
# 2009091305 HOU       NYJ                 6          24           66.0
# 2009091306 IND       JAC                14          12           68.0
# 2009091307 NO        DET                45          26           72.0
# 2009091308 TB        DAL                21          34           70.0
# 2009091309 ARI       SF                 16          20           82.0
# 2009091310 NYG       WAS                22          17           59.0
# 2009091311 SEA       STL                28           0           75.0
# 2009091312 GB        CHI                21          15           71.0
# 2009091400 NE        BUF                25          23           85.0
# 2009091401 OAK       SD                 20          24           72.0
# 2009092000 ATL       CAR                28          20           69.0
# 2009092001 DET       MIN                13          27           63.0
# 2009092002 GB        CIN                23          31           70.0
# 2009092003 JAC       ARI                17          30           79.0
# 2009092004 KC        OAK                10          13           67.0
# 2009092005 NYJ       NE                 16           9           71.0
# 2009092006 PHI       NO                 22          47           90.0
# 2009092007 TEN       HOU                31          34           73.0
# 2009092008 WAS       STL                 9           7           66.0
# 2009092009 BUF       TB                 32          20           86.0
# 2009092010 SF        SEA                23          10           73.0
# 2009092011 CHI       PIT                17          14           76.0
# 2009092012 DEN       CLE                27           6           72.0
# 2009092013 SD        BAL                26          31           75.0
# ...                                    ...         ...            ...
# 2018120901 CHI       LA                 15           6           79.0
# 2018120902 CLE       CAR                26          20           68.0
# 2018120903 GB        ATL                33          20           80.0
# 2018120904 HOU       IND                21          24           86.0
# 2018120905 KC        BAL                27          24           84.0
# 2018120906 MIA       NE                 34          33           69.0
# 2018120907 TB        NO                 14          28           74.0
# 2018120908 WAS       NYG                16          39           66.0
# 2018120909 LAC       CIN                26          21           63.0
# 2018120910 SF        DEN                20          14           80.0
# 2018120911 ARI       DET                 3          16           68.0
# 2018120912 DAL       PHI                29          23           91.0
# 2018120913 OAK       PIT                24          21           77.0
# 2018121000 SEA       MIN                20           7           58.0
# 2018121300 KC        LAC                28          29           80.0
# 2018121500 NYJ       HOU                22          29           75.0
# 2018121501 DEN       CLE                16          17           83.0
# 2018121600 ATL       ARI                39          14           82.0
# 2018121601 BAL       TB                 20          12           51.0
# 2018121602 BUF       DET                14          13           57.0
# 2018121603 CHI       GB                 24          17           77.0
# 2018121604 CIN       OAK                30          16           77.0
# 2018121605 IND       DAL                23           0           69.0
# 2018121606 JAX       WAS                12          16           51.0
# 2018121607 MIN       MIA                41          16           56.0
# 2018121608 NYG       TEN                 0          17           69.0
# 2018121609 SF        SEA                26          23           66.0
# 2018121610 PIT       NE                 17          10           73.0
# 2018121611 LA        PHI                23          30           87.0
# 2018121700 CAR       NO                  7          12           72.0
#
#                                  rush attempts
# game_id    home_team away_team
# 2009091000 PIT       TEN                  48.0
# 2009091300 ATL       MIA                  49.0
# 2009091301 BAL       KC                   58.0
# 2009091302 CAR       PHI                  62.0
# 2009091303 CIN       DEN                  47.0
# 2009091304 CLE       MIN                  57.0
# 2009091305 HOU       NYJ                  55.0
# 2009091306 IND       JAC                  58.0
# 2009091307 NO        DET                  55.0
# 2009091308 TB        DAL                  55.0
# 2009091309 ARI       SF                   42.0
# 2009091310 NYG       WAS                  52.0
# 2009091311 SEA       STL                  52.0
# 2009091312 GB        CHI                  53.0
# 2009091400 NE        BUF                  42.0
# 2009091401 OAK       SD                   55.0
# 2009092000 ATL       CAR                  62.0
# 2009092001 DET       MIN                  59.0
# 2009092002 GB        CIN                  52.0
# 2009092003 JAC       ARI                  48.0
# 2009092004 KC        OAK                  63.0
# 2009092005 NYJ       NE                   51.0
# 2009092006 PHI       NO                   50.0
# 2009092007 TEN       HOU                  55.0
# 2009092008 WAS       STL                  54.0
# 2009092009 BUF       TB                   54.0
# 2009092010 SF        SEA                  52.0
# 2009092011 CHI       PIT                  40.0
# 2009092012 DEN       CLE                  58.0
# 2009092013 SD        BAL                  53.0
# ...                                        ...
# 2018120901 CHI       LA                   48.0
# 2018120902 CLE       CAR                  46.0
# 2018120903 GB        ATL                  49.0
# 2018120904 HOU       IND                  48.0
# 2018120905 KC        BAL                  67.0
# 2018120906 MIA       NE                   51.0
# 2018120907 TB        NO                   54.0
# 2018120908 WAS       NYG                  56.0
# 2018120909 LAC       CIN                  57.0
# 2018120910 SF        DEN                  57.0
# 2018120911 ARI       DET                  52.0
# 2018120912 DAL       PHI                  50.0
# 2018120913 OAK       PIT                  44.0
# 2018121000 SEA       MIN                  63.0
# 2018121300 KC        LAC                  41.0
# 2018121500 NYJ       HOU                  48.0
# 2018121501 DEN       CLE                  48.0
# 2018121600 ATL       ARI                  49.0
# 2018121601 BAL       TB                   71.0
# 2018121602 BUF       DET                  63.0
# 2018121603 CHI       GB                   48.0
# 2018121604 CIN       OAK                  57.0
# 2018121605 IND       DAL                  61.0
# 2018121606 JAX       WAS                  59.0
# 2018121607 MIN       MIA                  60.0
# 2018121608 NYG       TEN                  61.0
# 2018121609 SF        SEA                  61.0
# 2018121610 PIT       NE                   44.0
# 2018121611 LA        PHI                  48.0
# 2018121700 CAR       NO                   55.0
#
# [2526 rows x 4 columns]

# %%
#lambda needs index
df_final = df_final.reset_index()
df_final
# Out:
#          game_id home_team away_team  home_score  away_score  pass attempts  \
# 0     2009091000       PIT       TEN          13          10           83.0
# 1     2009091300       ATL       MIA          19           7           72.0
# 2     2009091301       BAL        KC          38          23           71.0
# 3     2009091302       CAR       PHI          10          36           70.0
# 4     2009091303       CIN       DEN           7          12           68.0
# 5     2009091304       CLE       MIN          19          34           66.0
# 6     2009091305       HOU       NYJ           6          24           66.0
# 7     2009091306       IND       JAC          14          12           68.0
# 8     2009091307        NO       DET          45          26           72.0
# 9     2009091308        TB       DAL          21          34           70.0
# 10    2009091309       ARI        SF          16          20           82.0
# 11    2009091310       NYG       WAS          22          17           59.0
# 12    2009091311       SEA       STL          28           0           75.0
# 13    2009091312        GB       CHI          21          15           71.0
# 14    2009091400        NE       BUF          25          23           85.0
# 15    2009091401       OAK        SD          20          24           72.0
# 16    2009092000       ATL       CAR          28          20           69.0
# 17    2009092001       DET       MIN          13          27           63.0
# 18    2009092002        GB       CIN          23          31           70.0
# 19    2009092003       JAC       ARI          17          30           79.0
# 20    2009092004        KC       OAK          10          13           67.0
# 21    2009092005       NYJ        NE          16           9           71.0
# 22    2009092006       PHI        NO          22          47           90.0
# 23    2009092007       TEN       HOU          31          34           73.0
# 24    2009092008       WAS       STL           9           7           66.0
# 25    2009092009       BUF        TB          32          20           86.0
# 26    2009092010        SF       SEA          23          10           73.0
# 27    2009092011       CHI       PIT          17          14           76.0
# 28    2009092012       DEN       CLE          27           6           72.0
# 29    2009092013        SD       BAL          26          31           75.0
# ...          ...       ...       ...         ...         ...            ...
# 2496  2018120901       CHI        LA          15           6           79.0
# 2497  2018120902       CLE       CAR          26          20           68.0
# 2498  2018120903        GB       ATL          33          20           80.0
# 2499  2018120904       HOU       IND          21          24           86.0
# 2500  2018120905        KC       BAL          27          24           84.0
# 2501  2018120906       MIA        NE          34          33           69.0
# 2502  2018120907        TB        NO          14          28           74.0
# 2503  2018120908       WAS       NYG          16          39           66.0
# 2504  2018120909       LAC       CIN          26          21           63.0
# 2505  2018120910        SF       DEN          20          14           80.0
# 2506  2018120911       ARI       DET           3          16           68.0
# 2507  2018120912       DAL       PHI          29          23           91.0
# 2508  2018120913       OAK       PIT          24          21           77.0
# 2509  2018121000       SEA       MIN          20           7           58.0
# 2510  2018121300        KC       LAC          28          29           80.0
# 2511  2018121500       NYJ       HOU          22          29           75.0
# 2512  2018121501       DEN       CLE          16          17           83.0
# 2513  2018121600       ATL       ARI          39          14           82.0
# 2514  2018121601       BAL        TB          20          12           51.0
# 2515  2018121602       BUF       DET          14          13           57.0
# 2516  2018121603       CHI        GB          24          17           77.0
# 2517  2018121604       CIN       OAK          30          16           77.0
# 2518  2018121605       IND       DAL          23           0           69.0
# 2519  2018121606       JAX       WAS          12          16           51.0
# 2520  2018121607       MIN       MIA          41          16           56.0
# 2521  2018121608       NYG       TEN           0          17           69.0
# 2522  2018121609        SF       SEA          26          23           66.0
# 2523  2018121610       PIT        NE          17          10           73.0
# 2524  2018121611        LA       PHI          23          30           87.0
# 2525  2018121700       CAR        NO           7          12           72.0
#
#        rush attempts
# 0               48.0
# 1               49.0
# 2               58.0
# 3               62.0
# 4               47.0
# 5               57.0
# 6               55.0
# 7               58.0
# 8               55.0
# 9               55.0
# 10              42.0
# 11              52.0
# 12              52.0
# 13              53.0
# 14              42.0
# 15              55.0
# 16              62.0
# 17              59.0
# 18              52.0
# 19              48.0
# 20              63.0
# 21              51.0
# 22              50.0
# 23              55.0
# 24              54.0
# 25              54.0
# 26              52.0
# 27              40.0
# 28              58.0
# 29              53.0
# ...              ...
# 2496            48.0
# 2497            46.0
# 2498            49.0
# 2499            48.0
# 2500            67.0
# 2501            51.0
# 2502            54.0
# 2503            56.0
# 2504            57.0
# 2505            57.0
# 2506            52.0
# 2507            50.0
# 2508            44.0
# 2509            63.0
# 2510            41.0
# 2511            48.0
# 2512            48.0
# 2513            49.0
# 2514            71.0
# 2515            63.0
# 2516            48.0
# 2517            57.0
# 2518            61.0
# 2519            59.0
# 2520            60.0
# 2521            61.0
# 2522            61.0
# 2523            44.0
# 2524            48.0
# 2525            55.0
#
# [2526 rows x 7 columns]

# %%
def winner (row):
    if row['home_score'] > row['away_score']:
        return row['home_team']
    elif row['home_score'] < row['away_score']:
        return row['away_team']
    return 'TIE'
df_final['winner'] = df_final.apply (lambda row: winner(row), axis=1) 
df_final
# Out:
#          game_id home_team away_team  home_score  away_score  pass attempts  \
# 0     2009091000       PIT       TEN          13          10           83.0
# 1     2009091300       ATL       MIA          19           7           72.0
# 2     2009091301       BAL        KC          38          23           71.0
# 3     2009091302       CAR       PHI          10          36           70.0
# 4     2009091303       CIN       DEN           7          12           68.0
# 5     2009091304       CLE       MIN          19          34           66.0
# 6     2009091305       HOU       NYJ           6          24           66.0
# 7     2009091306       IND       JAC          14          12           68.0
# 8     2009091307        NO       DET          45          26           72.0
# 9     2009091308        TB       DAL          21          34           70.0
# 10    2009091309       ARI        SF          16          20           82.0
# 11    2009091310       NYG       WAS          22          17           59.0
# 12    2009091311       SEA       STL          28           0           75.0
# 13    2009091312        GB       CHI          21          15           71.0
# 14    2009091400        NE       BUF          25          23           85.0
# 15    2009091401       OAK        SD          20          24           72.0
# 16    2009092000       ATL       CAR          28          20           69.0
# 17    2009092001       DET       MIN          13          27           63.0
# 18    2009092002        GB       CIN          23          31           70.0
# 19    2009092003       JAC       ARI          17          30           79.0
# 20    2009092004        KC       OAK          10          13           67.0
# 21    2009092005       NYJ        NE          16           9           71.0
# 22    2009092006       PHI        NO          22          47           90.0
# 23    2009092007       TEN       HOU          31          34           73.0
# 24    2009092008       WAS       STL           9           7           66.0
# 25    2009092009       BUF        TB          32          20           86.0
# 26    2009092010        SF       SEA          23          10           73.0
# 27    2009092011       CHI       PIT          17          14           76.0
# 28    2009092012       DEN       CLE          27           6           72.0
# 29    2009092013        SD       BAL          26          31           75.0
# ...          ...       ...       ...         ...         ...            ...
# 2496  2018120901       CHI        LA          15           6           79.0
# 2497  2018120902       CLE       CAR          26          20           68.0
# 2498  2018120903        GB       ATL          33          20           80.0
# 2499  2018120904       HOU       IND          21          24           86.0
# 2500  2018120905        KC       BAL          27          24           84.0
# 2501  2018120906       MIA        NE          34          33           69.0
# 2502  2018120907        TB        NO          14          28           74.0
# 2503  2018120908       WAS       NYG          16          39           66.0
# 2504  2018120909       LAC       CIN          26          21           63.0
# 2505  2018120910        SF       DEN          20          14           80.0
# 2506  2018120911       ARI       DET           3          16           68.0
# 2507  2018120912       DAL       PHI          29          23           91.0
# 2508  2018120913       OAK       PIT          24          21           77.0
# 2509  2018121000       SEA       MIN          20           7           58.0
# 2510  2018121300        KC       LAC          28          29           80.0
# 2511  2018121500       NYJ       HOU          22          29           75.0
# 2512  2018121501       DEN       CLE          16          17           83.0
# 2513  2018121600       ATL       ARI          39          14           82.0
# 2514  2018121601       BAL        TB          20          12           51.0
# 2515  2018121602       BUF       DET          14          13           57.0
# 2516  2018121603       CHI        GB          24          17           77.0
# 2517  2018121604       CIN       OAK          30          16           77.0
# 2518  2018121605       IND       DAL          23           0           69.0
# 2519  2018121606       JAX       WAS          12          16           51.0
# 2520  2018121607       MIN       MIA          41          16           56.0
# 2521  2018121608       NYG       TEN           0          17           69.0
# 2522  2018121609        SF       SEA          26          23           66.0
# 2523  2018121610       PIT        NE          17          10           73.0
# 2524  2018121611        LA       PHI          23          30           87.0
# 2525  2018121700       CAR        NO           7          12           72.0
#
#        rush attempts winner
# 0               48.0    PIT
# 1               49.0    ATL
# 2               58.0    BAL
# 3               62.0    PHI
# 4               47.0    DEN
# 5               57.0    MIN
# 6               55.0    NYJ
# 7               58.0    IND
# 8               55.0     NO
# 9               55.0    DAL
# 10              42.0     SF
# 11              52.0    NYG
# 12              52.0    SEA
# 13              53.0     GB
# 14              42.0     NE
# 15              55.0     SD
# 16              62.0    ATL
# 17              59.0    MIN
# 18              52.0    CIN
# 19              48.0    ARI
# 20              63.0    OAK
# 21              51.0    NYJ
# 22              50.0     NO
# 23              55.0    HOU
# 24              54.0    WAS
# 25              54.0    BUF
# 26              52.0     SF
# 27              40.0    CHI
# 28              58.0    DEN
# 29              53.0    BAL
# ...              ...    ...
# 2496            48.0    CHI
# 2497            46.0    CLE
# 2498            49.0     GB
# 2499            48.0    IND
# 2500            67.0     KC
# 2501            51.0    MIA
# 2502            54.0     NO
# 2503            56.0    NYG
# 2504            57.0    LAC
# 2505            57.0     SF
# 2506            52.0    DET
# 2507            50.0    DAL
# 2508            44.0    OAK
# 2509            63.0    SEA
# 2510            41.0    LAC
# 2511            48.0    HOU
# 2512            48.0    CLE
# 2513            49.0    ATL
# 2514            71.0    BAL
# 2515            63.0    BUF
# 2516            48.0    CHI
# 2517            57.0    CIN
# 2518            61.0    IND
# 2519            59.0    WAS
# 2520            60.0    MIN
# 2521            61.0    TEN
# 2522            61.0     SF
# 2523            44.0    PIT
# 2524            48.0    PHI
# 2525            55.0     NO
#
# [2526 rows x 8 columns]

# %%
#nuni = n_games_df.groupby('game_id')
#nuni.head()
#end_game = n_games_df.groupby(['game_id'])['play_id'].max
#end_game()
#homescore = n_games_df.groupby(['game_id'])['posteam_score_post'].max
#awayscore = n_games_df.groupby(['game_id'])['defteam_score_post'].max
#awayscore()
# ha ha n_games_df = n_games_df.dropna()
#n_games_df
#import csv 
#def winner (row):
#    if pd.isna(row['game_seconds_remaining']) == True:
#    if row['game_seconds_remaining'] != Nan(row['games_seconds_remaining']):
#       return 'nanner '
#    elif row['game_id'] != row['game_id'].shift():
#        return 'game id hit'
#    elif row['score_differential_post'] > 0 and row['game_half'] == 'Half2' and int(row['game_seconds_remaining']) == 0:
#       return row['home_team']
#    elif row['score_differential_post'] < 0 and row['game_half'] == 'Half2' and int(row['game_seconds_remaining']) == 0:
#       return row['away_team']
#    elif row['score_differential_post'] > 0 and row['game_half'] == 'Overtime':
#       return 'home team overtime'
#       return row['home_team']
#    elif row['score_differential_post'] < 0 and row['game_half'] == 'Overtime':
#       return 'away team overtime'
#       return row['away_team']
#    elif row['score_differential_post'] > 0 and row['game_half'] != 'Half2' and int(row['game_seconds_remaining']) != 0:
#       return 'what'
#    elif row['score_differential_post'] < 0 and row['game_half'] != 'Half2' and int(row['game_seconds_remaining']) != 0:
#       return 'twhat'
#    return 'missed '
#    return row['game_seconds_remaining']
#n_games_df['winner'] = n_games_df.apply (lambda row: winner(row), axis=1) 
#n_games_df

#using this section
#setitup = n_games_df.groupby(['game_id', 'home_team','away_team','total_home_score', 'total_away_score']).count
#setitupmaxh = n_games_df.groupby(['game_id'])['total_home_score'].max()
setitupmaxa = n_games_df.groupby(['game_id'])['total_away_score'].max()
#data.groupby(['col1', 'col2'])['col3'].mean()
#setitupmaxa

#passh = n_games_df.groupby(['game_id'])['pass_attempt'].sum
#passh()
#runh = n_games_df.groupby(['game_id'])['rush_attempt'].sum
#runh()
def offense (row):
    if row['home_team'] == row['posteam'] and int(row['pass_attempt']) == 1:
        return 'homepass'
    elif row['away_team'] == row['posteam'] and int(row['pass_attempt']) == 1:
        return 'awaypass'
    elif row['home_team'] == row['posteam'] and int(row['rush_attempt']) == 1:
        return 'homerush'
    elif row['away_team'] == row['posteam'] and int(row['rush_attempt']) == 1:
        return 'awayrush'
    return 'NA'
n_games_df['offense'] = n_games_df.apply (lambda row: offense(row), axis=1) 
oc = n_games_df['offense'].value_counts()
#oc
plays = n_games_df.groupby(['game_id'])['offense'].count
#plays()
n_games_df()

#setitup()

#winnerc = n_games_df.groupby(['winner']).count
#winnerc()
#avg_fare = moc_df.groupby(['city'])['fare'].mean()
#pplays = n_games_df.groupby(['posteam'])['pass_attempt'].sum
#pplays()
#rplays = n_games_df.groupby(['posteam'])['rush_attempt'].sum
#rplays()

#urb = all_cities.loc[all_cities["City Type"]== "Urban"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-1587c933a351> in <module>
#      60 plays = n_games_df.groupby(['game_id'])['offense'].count
#      61 #plays()
# ---> 62 n_games_df()
#      63
#      64 #setitup()
#
# TypeError: 'DataFrame' object is not callable

# %%
def offense (row):
    if row['home_team'] == row['posteam'] and int(row['pass_attempt']) == 1:
        return 'homepass'
    elif row['away_team'] == row['posteam'] and int(row['pass_attempt']) == 1:
        return 'awaypass'
    elif row['home_team'] == row['posteam'] and int(row['rush_attempt']) == 1:
        return 'homerush'
    elif row['away_team'] == row['posteam'] and int(row['rush_attempt']) == 1:
        return 'awayrush'
    return 'NA'
n_games_df['offense'] = n_games_df.apply (lambda row: offense(row), axis=1) 
oc = n_games_df['offense'].value_counts()
#oc
plays = n_games_df.groupby(['game_id'])['offense'].count

# %%
#n_games_df
total_plays = n_games_df.groupby('offense')['game_id'].count()
total_plays
# Out:
# offense
# NA          124661
# awaypass     94614
# awayrush     66725
# homepass     93653
# homerush     69718
# Name: game_id, dtype: int64

# %%
colors = ["gold", "skyblue", "coral","red","orange"]
explode = (0.1, 0.1, 0.1)
#colors
plt.pie(total_plays, labels=total_plays.keys(), colors= colors, shadow=True, startangle=280, autopct="%1.1f%%",
       explode=None)
plt.title('% of Play Types')
# Out:
# Text(0.5, 1.0, '% of Play Types')

# %%
setitup = n_games_df.groupby(['game_id', 'home_team','away_team'])
setitup['total_home_score'].max()
setitup['total_away_score'].max()
df_final=pd.DataFrame({'home_score':setitup['total_home_score'].max(),'away_score':setitup['total_away_score'].max()})
df_final
# Out:
#                                 home_score  away_score
# game_id    home_team away_team
# 2009091000 PIT       TEN                13          10
# 2009091300 ATL       MIA                19           7
# 2009091301 BAL       KC                 38          23
# 2009091302 CAR       PHI                10          36
# 2009091303 CIN       DEN                 7          12
# 2009091304 CLE       MIN                19          34
# 2009091305 HOU       NYJ                 6          24
# 2009091306 IND       JAC                14          12
# 2009091307 NO        DET                45          26
# 2009091308 TB        DAL                21          34
# 2009091309 ARI       SF                 16          20
# 2009091310 NYG       WAS                22          17
# 2009091311 SEA       STL                28           0
# 2009091312 GB        CHI                21          15
# 2009091400 NE        BUF                25          23
# 2009091401 OAK       SD                 20          24
# 2009092000 ATL       CAR                28          20
# 2009092001 DET       MIN                13          27
# 2009092002 GB        CIN                23          31
# 2009092003 JAC       ARI                17          30
# 2009092004 KC        OAK                10          13
# 2009092005 NYJ       NE                 16           9
# 2009092006 PHI       NO                 22          47
# 2009092007 TEN       HOU                31          34
# 2009092008 WAS       STL                 9           7
# 2009092009 BUF       TB                 32          20
# 2009092010 SF        SEA                23          10
# 2009092011 CHI       PIT                17          14
# 2009092012 DEN       CLE                27           6
# 2009092013 SD        BAL                26          31
# ...                                    ...         ...
# 2018120901 CHI       LA                 15           6
# 2018120902 CLE       CAR                26          20
# 2018120903 GB        ATL                33          20
# 2018120904 HOU       IND                21          24
# 2018120905 KC        BAL                27          24
# 2018120906 MIA       NE                 34          33
# 2018120907 TB        NO                 14          28
# 2018120908 WAS       NYG                16          39
# 2018120909 LAC       CIN                26          21
# 2018120910 SF        DEN                20          14
# 2018120911 ARI       DET                 3          16
# 2018120912 DAL       PHI                29          23
# 2018120913 OAK       PIT                24          21
# 2018121000 SEA       MIN                20           7
# 2018121300 KC        LAC                28          29
# 2018121500 NYJ       HOU                22          29
# 2018121501 DEN       CLE                16          17
# 2018121600 ATL       ARI                39          14
# 2018121601 BAL       TB                 20          12
# 2018121602 BUF       DET                14          13
# 2018121603 CHI       GB                 24          17
# 2018121604 CIN       OAK                30          16
# 2018121605 IND       DAL                23           0
# 2018121606 JAX       WAS                12          16
# 2018121607 MIN       MIA                41          16
# 2018121608 NYG       TEN                 0          17
# 2018121609 SF        SEA                26          23
# 2018121610 PIT       NE                 17          10
# 2018121611 LA        PHI                23          30
# 2018121700 CAR       NO                  7          12
#
# [2526 rows x 2 columns]

# %%
#lambda needs index
df_final = df_final.reset_index()
df_final
# Out:
#          game_id home_team away_team  home_score  away_score
# 0     2009091000       PIT       TEN          13          10
# 1     2009091300       ATL       MIA          19           7
# 2     2009091301       BAL        KC          38          23
# 3     2009091302       CAR       PHI          10          36
# 4     2009091303       CIN       DEN           7          12
# 5     2009091304       CLE       MIN          19          34
# 6     2009091305       HOU       NYJ           6          24
# 7     2009091306       IND       JAC          14          12
# 8     2009091307        NO       DET          45          26
# 9     2009091308        TB       DAL          21          34
# 10    2009091309       ARI        SF          16          20
# 11    2009091310       NYG       WAS          22          17
# 12    2009091311       SEA       STL          28           0
# 13    2009091312        GB       CHI          21          15
# 14    2009091400        NE       BUF          25          23
# 15    2009091401       OAK        SD          20          24
# 16    2009092000       ATL       CAR          28          20
# 17    2009092001       DET       MIN          13          27
# 18    2009092002        GB       CIN          23          31
# 19    2009092003       JAC       ARI          17          30
# 20    2009092004        KC       OAK          10          13
# 21    2009092005       NYJ        NE          16           9
# 22    2009092006       PHI        NO          22          47
# 23    2009092007       TEN       HOU          31          34
# 24    2009092008       WAS       STL           9           7
# 25    2009092009       BUF        TB          32          20
# 26    2009092010        SF       SEA          23          10
# 27    2009092011       CHI       PIT          17          14
# 28    2009092012       DEN       CLE          27           6
# 29    2009092013        SD       BAL          26          31
# ...          ...       ...       ...         ...         ...
# 2496  2018120901       CHI        LA          15           6
# 2497  2018120902       CLE       CAR          26          20
# 2498  2018120903        GB       ATL          33          20
# 2499  2018120904       HOU       IND          21          24
# 2500  2018120905        KC       BAL          27          24
# 2501  2018120906       MIA        NE          34          33
# 2502  2018120907        TB        NO          14          28
# 2503  2018120908       WAS       NYG          16          39
# 2504  2018120909       LAC       CIN          26          21
# 2505  2018120910        SF       DEN          20          14
# 2506  2018120911       ARI       DET           3          16
# 2507  2018120912       DAL       PHI          29          23
# 2508  2018120913       OAK       PIT          24          21
# 2509  2018121000       SEA       MIN          20           7
# 2510  2018121300        KC       LAC          28          29
# 2511  2018121500       NYJ       HOU          22          29
# 2512  2018121501       DEN       CLE          16          17
# 2513  2018121600       ATL       ARI          39          14
# 2514  2018121601       BAL        TB          20          12
# 2515  2018121602       BUF       DET          14          13
# 2516  2018121603       CHI        GB          24          17
# 2517  2018121604       CIN       OAK          30          16
# 2518  2018121605       IND       DAL          23           0
# 2519  2018121606       JAX       WAS          12          16
# 2520  2018121607       MIN       MIA          41          16
# 2521  2018121608       NYG       TEN           0          17
# 2522  2018121609        SF       SEA          26          23
# 2523  2018121610       PIT        NE          17          10
# 2524  2018121611        LA       PHI          23          30
# 2525  2018121700       CAR        NO           7          12
#
# [2526 rows x 5 columns]

# %%
def winner (row):
    if row['home_score'] > row['away_score']:
        return row['home_team']
    elif row['home_score'] < row['away_score']:
        return row['away_team']
    return 'TIE'
df_final['winner'] = df_final.apply (lambda row: winner(row), axis=1) 
#oc = df_final['winner'].value_counts()
#oc
df_final
#plays = n_games_df.groupby(['game_id'])['offense'].count
# Out:
#          game_id home_team away_team  home_score  away_score winner
# 0     2009091000       PIT       TEN          13          10    PIT
# 1     2009091300       ATL       MIA          19           7    ATL
# 2     2009091301       BAL        KC          38          23    BAL
# 3     2009091302       CAR       PHI          10          36    PHI
# 4     2009091303       CIN       DEN           7          12    DEN
# 5     2009091304       CLE       MIN          19          34    MIN
# 6     2009091305       HOU       NYJ           6          24    NYJ
# 7     2009091306       IND       JAC          14          12    IND
# 8     2009091307        NO       DET          45          26     NO
# 9     2009091308        TB       DAL          21          34    DAL
# 10    2009091309       ARI        SF          16          20     SF
# 11    2009091310       NYG       WAS          22          17    NYG
# 12    2009091311       SEA       STL          28           0    SEA
# 13    2009091312        GB       CHI          21          15     GB
# 14    2009091400        NE       BUF          25          23     NE
# 15    2009091401       OAK        SD          20          24     SD
# 16    2009092000       ATL       CAR          28          20    ATL
# 17    2009092001       DET       MIN          13          27    MIN
# 18    2009092002        GB       CIN          23          31    CIN
# 19    2009092003       JAC       ARI          17          30    ARI
# 20    2009092004        KC       OAK          10          13    OAK
# 21    2009092005       NYJ        NE          16           9    NYJ
# 22    2009092006       PHI        NO          22          47     NO
# 23    2009092007       TEN       HOU          31          34    HOU
# 24    2009092008       WAS       STL           9           7    WAS
# 25    2009092009       BUF        TB          32          20    BUF
# 26    2009092010        SF       SEA          23          10     SF
# 27    2009092011       CHI       PIT          17          14    CHI
# 28    2009092012       DEN       CLE          27           6    DEN
# 29    2009092013        SD       BAL          26          31    BAL
# ...          ...       ...       ...         ...         ...    ...
# 2496  2018120901       CHI        LA          15           6    CHI
# 2497  2018120902       CLE       CAR          26          20    CLE
# 2498  2018120903        GB       ATL          33          20     GB
# 2499  2018120904       HOU       IND          21          24    IND
# 2500  2018120905        KC       BAL          27          24     KC
# 2501  2018120906       MIA        NE          34          33    MIA
# 2502  2018120907        TB        NO          14          28     NO
# 2503  2018120908       WAS       NYG          16          39    NYG
# 2504  2018120909       LAC       CIN          26          21    LAC
# 2505  2018120910        SF       DEN          20          14     SF
# 2506  2018120911       ARI       DET           3          16    DET
# 2507  2018120912       DAL       PHI          29          23    DAL
# 2508  2018120913       OAK       PIT          24          21    OAK
# 2509  2018121000       SEA       MIN          20           7    SEA
# 2510  2018121300        KC       LAC          28          29    LAC
# 2511  2018121500       NYJ       HOU          22          29    HOU
# 2512  2018121501       DEN       CLE          16          17    CLE
# 2513  2018121600       ATL       ARI          39          14    ATL
# 2514  2018121601       BAL        TB          20          12    BAL
# 2515  2018121602       BUF       DET          14          13    BUF
# 2516  2018121603       CHI        GB          24          17    CHI
# 2517  2018121604       CIN       OAK          30          16    CIN
# 2518  2018121605       IND       DAL          23           0    IND
# 2519  2018121606       JAX       WAS          12          16    WAS
# 2520  2018121607       MIN       MIA          41          16    MIN
# 2521  2018121608       NYG       TEN           0          17    TEN
# 2522  2018121609        SF       SEA          26          23     SF
# 2523  2018121610       PIT        NE          17          10    PIT
# 2524  2018121611        LA       PHI          23          30    PHI
# 2525  2018121700       CAR        NO           7          12     NO
#
# [2526 rows x 6 columns]

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types

# Build the scatter plots for each city types

# Incorporate the other graph properties

# Create a legend

# Incorporate a text label regarding circle size

# Save Figure

# %%
city_df = pd.DataFrame(city_data_to_load)
















ride_df = pd.DataFrame(ride_data_to_load)
#ride_df
# Read the City and Ride Data
#merged_on_city
moc_df = pd.merge(city_df, ride_df, on="city")
#print(moc_df)

#merged_on_city_df.plot()
#should be doing average fare per city first
avg_fare = moc_df.groupby(['city'])['fare'].mean()
#there is garbage row from above? seems to be ok
#do I do rides here, feel like I am guessing
rides = moc_df.groupby(['city'])['ride_id'].count()
AuntDot = moc_df.groupby(['city'])['driver_count'].sum()
typo = moc_df.groupby(['city'])['type'].unique()
#print(typo)

all_cities = pd.DataFrame({"Average Fare per City":avg_fare,
                 "Number of Rides": rides,
                 "Number of Drivers": AuntDot,
                 "City Type": typo
})
#print(all_cities)
urb = all_cities.loc[all_cities["City Type"]== "Urban"]
sub = all_cities.loc[all_cities["City Type"]== "Suburban"]
rur = all_cities.loc[all_cities["City Type"]== "Rural"]
#print(rur)

colors = ["gold", "skyblue", "coral"]

# back up to do labels, colors???? how come there is no default
# city type ---- colors
plt.text(45, 40, 'Note:\nCircle size correlates with driver count per city.', fontsize=10)
plt.text(30, 40, 'City Grid', fontsize=10)
plt.text(30, 38, 'Urban', fontsize=10,color=colors[1])
plt.text(30, 36, 'Suburban', fontsize=10,color=colors[0])
plt.text(30, 34, 'Rural', fontsize=10,color=colors[2])
plt.title("Pyber Ride Sharing Data (2016)")
plt.ylabel("Average Fare per City")
plt.xlabel("Total Rides per City")
# add a grid
plt.grid()
# now do City type
#ctype = moc_df.groupby(['type'])['type'].unique()
#ctype
plt.scatter(sub["Number of Rides"], sub["Average Fare per City"], color = "gold", edgecolors="black", 
         s = sub["Number of Drivers"], label = "Suburban", alpha = 1, linewidth = 1, marker="o")
plt.scatter(urb["Number of Rides"], urb["Average Fare per City"], color = "skyblue", edgecolors="black", 
         s = urb["Number of Drivers"], label = "Urban", alpha = 1, linewidth = 1, marker="o")
plt.scatter(rur["Number of Rides"], rur["Average Fare per City"], color = "coral", edgecolors="black", 
         s = rur["Number of Drivers"], label = "Rural", alpha = 1, linewidth = 1, marker="o")
#plt.scatter(rides, avg_fare, marker="o", edgecolors="black", color=colors[0], alpha=0.75, s=AuntDot)
#save it
plt.savefig("../Images/RideSharingBubblePlot.png", bbox_inches="tight")
# Combine the data into a single dataset
#plt.scatter(city,driver_count)
# Display the data table for preview
#merged_on_city_df.plot()  # plots all columns against index
#merged_on_city_df.plot(kind='scatter',x='driver_count',y='city') # scatter plot
#plt.scatter(city, driver_count, marker=\"o\", facecolors=\"red\", edgecolors=\"black"),\n
#,"\n",
#moc_df.plot(kind='density')  # estimate density function where did i find this, start denoting

# %%
# Show plot
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents

# Build Pie Chart

# Save Figure

# %%
#working here
#type percents        
total_fares = moc_df.groupby('type')['fare'].sum()
#total_fares
#doing colors again
colors = ["gold", "skyblue", "coral"]
explode = (0.03, 0.03, 0.1)
#colors
plt.pie(total_fares, labels=total_fares.keys(), colors= colors, shadow=True, startangle=280, autopct="%1.1f%%",
       explode=explode)
plt.title('% of Total Fares by City Type - Pacman')
# Out:
# Text(0.5, 1.0, '% of Total Fares by City Type - Pacman')

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents

# Build Pie Chart

# Save Figure

# %%
#working here
#working here
#type percents        
total_fares = moc_df.groupby('type')['ride_id'].count()
#total_fares
#doing colors again
colors = ["gold", "skyblue", "coral"]
explode = (0.03, 0.03, 0.1)
#colors
plt.pie(total_fares, labels=total_fares.keys(), colors= colors, shadow=True, startangle=280, autopct="%1.1f%%",
       explode=explode)
plt.title('% of Total Rides by City Type - Pacman')
# Out:
# Text(0.5, 1.0, '% of Total Rides by City Type - Pacman')

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents

# Build Pie Charts

# Save Figure

# %%
#working here
#type percents        
total_fares = moc_df.groupby('type')['driver_count'].sum()
#total_fares
#doing colors again
colors = ["gold", "skyblue", "coral"]
explode = (0.03, 0.03, 0.1)
#colors
plt.pie(total_fares, labels=total_fares.keys(), colors= colors, shadow=True, startangle=280, autopct="%1.1f%%",
       explode=explode)
plt.title('% of Total Drivers by City Type - Pacman')
# Out:
# Text(0.5, 1.0, '% of Total Drivers by City Type - Pacman')

# %%
# Show Figure
plt.show()
